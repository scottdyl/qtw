# %%
import pandas as pd

# %%
pd.read_csv("test.csv", header=0).tail()
# Out:
#                                                 Subject  \
# 9348             Preferred Non-Smoker Rates for Smokers
# 9349  How to get 10,000 FREE hits per day to any web...
# 9350                                Cannabis Difference
# 9351                              [ILUG] WILSON  KAMELA
# 9352                                                NaN
#
#                                                    From  \
# 9348                            IQ - TBA <tba@insiq.us>
# 9349                               Mike <raye@yahoo.lv>
# 9350                   "Mr. Clean" <cweqx@dialix.oz.au>
# 9351  "wilsonkamela400@netscape.net" <wilsonkamela50...
# 9352                                                NaN
#
#                                                    Body  isSpam
# 9348  b' \t Preferred Non-Smoker\n \t\n Just what th...       1
# 9349  b'Dear Subscriber,\n\nIf I could show you a wa...       1
# 9350  b'****Mid-Summer Customer Appreciation SALE!**...       1
# ...

# %%
pd.read_csv("test.csv", header=0).head()
# Out:
#                                           Subject  \
# 0                        Re: New Sequences Window
# 1                       [zzzzteana] RE: Alexander
# 2                       [zzzzteana] Moscow bomber
# 3           [IRR] Klez: The Virus That  Won't Die
# 4  Re: [zzzzteana] Nothing like mama used to make
#
#                                         From  \
# 0             Robert Elz <kre@munnari.OZ.AU>
# 1  Steve Burt <Steve_Burt@cursor-system.com>
# 2                Tim Chapman <timc@2ubh.com>
# 3           Monty Solomon <monty@roscom.com>
# 4  Stewart Smith <Stewart.Smith@ee.ed.ac.uk>
#
#                                                 Body  isSpam
# 0  b'    Date:        Wed, 21 Aug 2002 10:54:46 -...       0
# 1  b"Martin A posted:\nTassos Papadopoulos, the G...       0
# 2  b"Man Threatens Explosion In Moscow \n\nThursd...       0
# 3  b"Klez: The Virus That Won't Die\n \nAlready t...       0
# 4  b">  in adding cream to spaghetti carbonara, w...       0
